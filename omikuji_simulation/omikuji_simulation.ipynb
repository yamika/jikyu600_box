# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
prize = [-250,0,1000]
trial_num = 500

# %%
result1 = np.random.choice(prize,trial_num,p=[0.6,0.25,0.15])
score1 = result1.cumsum()

result2 = np.random.choice(prize,trial_num,p=[0.6,0.25,0.15])
score2 = result2.cumsum()

result3 = np.random.choice(prize,trial_num,p=[0.6,0.25,0.15])
score3 = result3.cumsum()

# %%
plt.hist(result1,range=(-250,1500))
# Out:
# (array([ 295.,  125.,    0.,    0.,    0.,    0.,    0.,   80.,    0.,    0.]),
#  array([ -250.,   -75.,   100.,   275.,   450.,   625.,   800.,   975.,
#          1150.,  1325.,  1500.]),
#  <a list of 10 Patch objects>)

# %%
variance = (250-500)*(250-500)+0+(1500-500)*(1500-500)
print(variance)
standard_deviation = np.sqrt(variance)
print(standard_deviation)
# Out:
# 1062500
# 1030.7764064

# %%
count = np.arange(0,trial_num)
ex_value= np.zeros(trial_num)+500
plt.ylim(-2000,10000)
plt.plot(count,score1,'bo')
plt.plot(count,ex_value,'r-')
plt.plot(count,ex_value+standard_deviation,'r--')
plt.plot(count,ex_value-standard_deviation,'r--')

# %%
plt.plot(count,score2,'co')
plt.plot(count,ex_value,'r-')
plt.plot(count,ex_value+standard_deviation,'r--')
plt.plot(count,ex_value-standard_deviation,'r--')

# %%
plt.plot(count,score3,'yo')
plt.plot(count,ex_value,'r-')
plt.plot(count,ex_value+standard_deviation,'r--')
plt.plot(count,ex_value-standard_deviation,'r--')
